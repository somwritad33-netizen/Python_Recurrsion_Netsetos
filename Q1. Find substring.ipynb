# %%
s='NETSETOS'
s1=list(s)
print(s1)

target ='SET'

# %%
from itertools import combinations

l= list(combinations(s1,3))
# print(l)

l1=  [''.join(i) for i in l]


if target in l1:
    print("Yes")
else:
    print("No")

# %% [markdown]
# #--------------------------------RECURSION

# %%
print(s[0:3])

# %%
def find_substring(s):
    l=[]
    if len(s)<1:
        return []
    else:
        return [s[0:3]]+find_substring(s[1:])

print(find_substring(s))
  

if target in find_substring(s):
    print("Yes")
else:
    print("No")
