# %%
import regex as re

# %%
s= 'NET1SET2O3S4'

s1= re.sub(r'[a-zA-Z]', '', s)
s1
s2=int(s1)
s2

# %%
1234%10

# %%
def rev_digits(n):
    if n<1:
        return ''
    else:
        return str(n%10)+rev_digits(n//10)






print(int(rev_digits(s2)))
